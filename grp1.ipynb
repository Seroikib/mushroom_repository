# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("mushroom.csv")
print(df.info)
print(df.head(10))
# Out:
# <bound method DataFrame.info of      cap-shape cap-surface cap-color bruises%3F  odor gill-attachment  \
# 0         b'x'        b's'      b'n'       b't'  b'p'            b'f'
# 1         b'x'        b's'      b'y'       b't'  b'a'            b'f'
# 2         b'b'        b's'      b'w'       b't'  b'l'            b'f'
# 3         b'x'        b'y'      b'w'       b't'  b'p'            b'f'
# 4         b'x'        b's'      b'g'       b'f'  b'n'            b'f'
# ...        ...         ...       ...        ...   ...             ...
# 8119      b'k'        b's'      b'n'       b'f'  b'n'            b'a'
# 8120      b'x'        b's'      b'n'       b'f'  b'n'            b'a'
# 8121      b'f'        b's'      b'n'       b'f'  b'n'            b'a'
# 8122      b'k'        b'y'      b'n'       b'f'  b'y'            b'f'
# 8123      b'x'        b's'      b'n'       b'f'  b'n'            b'a'
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# ...

# %%
print(df.isnull().sum)
# Out:
# <bound method DataFrame.sum of       cap-shape  cap-surface  cap-color  bruises%3F   odor  gill-attachment  \
# 0         False        False      False       False  False            False
# 1         False        False      False       False  False            False
# 2         False        False      False       False  False            False
# 3         False        False      False       False  False            False
# 4         False        False      False       False  False            False
# ...         ...          ...        ...         ...    ...              ...
# 8119      False        False      False       False  False            False
# 8120      False        False      False       False  False            False
# 8121      False        False      False       False  False            False
# 8122      False        False      False       False  False            False
# 8123      False        False      False       False  False            False
#
# ...

# %%
df_cleaned=df.dropna()

# %%
print("Missing values after Dropping",df_cleaned.isnull().sum)
# Out:
# Missing values after Dropping <bound method DataFrame.sum of       cap-shape  cap-surface  cap-color  bruises%3F   odor  gill-attachment  \
# 0         False        False      False       False  False            False
# 1         False        False      False       False  False            False
# 2         False        False      False       False  False            False
# 3         False        False      False       False  False            False
# 4         False        False      False       False  False            False
# ...         ...          ...        ...         ...    ...              ...
# 8119      False        False      False       False  False            False
# 8120      False        False      False       False  False            False
# 8121      False        False      False       False  False            False
# 8122      False        False      False       False  False            False
# 8123      False        False      False       False  False            False
# ...

# %%
df_cleaned.to_csv("cleaned_mushroom.csv", index=False)#saving cleaned dataset

# %%
print(df['class'].value_counts())
# Out:
# class
# b'e'    4208
# b'p'    3916
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="class",palette="coolwarm")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_35984\224355977.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="class",palette="coolwarm")

# %%
for column in df.columns:
  print(f"{column}:{df[column].unique()}")
# Out:
# cap-shape:["b'x'" "b'b'" "b's'" "b'f'" "b'k'" "b'c'"]
# cap-surface:["b's'" "b'y'" "b'f'" "b'g'"]
# cap-color:["b'n'" "b'y'" "b'w'" "b'g'" "b'e'" "b'p'" "b'b'" "b'u'" "b'c'" "b'r'"]
# bruises%3F:["b't'" "b'f'"]
# odor:["b'p'" "b'a'" "b'l'" "b'n'" "b'f'" "b'c'" "b'y'" "b's'" "b'm'"]
# gill-attachment:["b'f'" "b'a'"]
# gill-spacing:["b'c'" "b'w'"]
# gill-size:["b'n'" "b'b'"]
# gill-color:["b'k'" "b'n'" "b'g'" "b'p'" "b'w'" "b'h'" "b'u'" "b'e'" "b'b'" "b'r'"
#  "b'y'" "b'o'"]
# stalk-shape:["b'e'" "b't'"]
# stalk-root:["b'e'" "b'c'" "b'b'" "b'r'" "b'?'"]
# stalk-surface-above-ring:["b's'" "b'f'" "b'k'" "b'y'"]
# stalk-surface-below-ring:["b's'" "b'f'" "b'y'" "b'k'"]
# stalk-color-above-ring:["b'w'" "b'g'" "b'p'" "b'n'" "b'b'" "b'e'" "b'o'" "b'c'" "b'y'"]
# stalk-color-below-ring:["b'w'" "b'p'" "b'g'" "b'b'" "b'n'" "b'e'" "b'y'" "b'o'" "b'c'"]
# veil-type:["b'p'"]
# veil-color:["b'w'" "b'n'" "b'o'" "b'y'"]
# ring-number:["b'o'" "b't'" "b'n'"]
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.apply(lambda x: pd.factorize(x)[0]).corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cap-shape                 8124 non-null   object
#  1   cap-surface               8124 non-null   object
#  2   cap-color                 8124 non-null   object
#  3   bruises%3F                8124 non-null   object
#  4   odor                      8124 non-null   object
#  5   gill-attachment           8124 non-null   object
#  6   gill-spacing              8124 non-null   object
#  7   gill-size                 8124 non-null   object
#  8   gill-color                8124 non-null   object
#  9   stalk-shape               8124 non-null   object
#  10  stalk-root                8124 non-null   object
#  11  stalk-surface-above-ring  8124 non-null   object
#  12  stalk-surface-below-ring  8124 non-null   object
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="cap-shape", hue="class", data=df, palette="coolwarm")
plt.title("Cap Shape Distribution by Class")
plt.xlabel("Cap Shape")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="cap-surface", hue="class", data=df, palette="coolwarm")
plt.title("Cap Surface Distribution by Class")
plt.xlabel("Cap Surface")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="cap-color", hue="class", data=df, palette="coolwarm")
plt.title("Cap Color Distribution by Class")
plt.xlabel("Cap Color")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="bruises%3F", hue="class", data=df, palette="coolwarm")
plt.title("Bruises%3F Distribution by Class")
plt.xlabel("Bruises")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="odor", hue="class", data=df, palette="coolwarm")
plt.title("Odor Distribution by Class")
plt.xlabel("Odor")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="gill-attachment", hue="class", data=df, palette="coolwarm")
plt.title("Gill Attachment Distribution by Class")
plt.xlabel("Gill Attachment")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="gill-spacing", hue="class", data=df, palette="coolwarm")
plt.title("Gill Spacing Distribution by Class")
plt.xlabel("Gill Spacing")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="gill-size", hue="class", data=df, palette="coolwarm")
plt.title("Gill Size Distribution by Class")
plt.xlabel("Gill Size")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="gill-color", hue="class", data=df, palette="coolwarm")
plt.title("Gill Color Distribution by Class")
plt.xlabel("Gill Color")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="stalk-shape", hue="class", data=df, palette="coolwarm")
plt.title("Stalk Shape Distribution by Class")
plt.xlabel("Stalk Shape")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="stalk-root", hue="class", data=df, palette="coolwarm")
plt.title("Stalk Root Distribution by Class")
plt.xlabel("Stalk Root")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="stalk-surface-above-ring", hue="class", data=df, palette="coolwarm")
plt.title("Stalk Surface Above Ring Distribution by Class")
plt.xlabel("Stalk Surface Above Ring")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="stalk-surface-below-ring", hue="class", data=df, palette="coolwarm")
plt.title("Stalk Surface Below Ring Distribution by Class")
plt.xlabel("Stalk Surface Below Ring")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="stalk-color-above-ring", hue="class", data=df, palette="coolwarm")
plt.title("Stalk Color Above Ring Distribution by Class")
plt.xlabel("Stalk Color Above Ring")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="stalk-color-below-ring", hue="class", data=df, palette="coolwarm")
plt.title("Stalk Color Below Ring Distribution by Class")
plt.xlabel("Stalk Color Below Ring")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="veil-type", hue="class", data=df, palette="coolwarm")
plt.title("Veil Type Distribution by Class")
plt.xlabel("Veil Type")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="veil-color", hue="class", data=df, palette="coolwarm")
plt.title("Veil Color Distribution by Class")
plt.xlabel("Veil Color")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="ring-number", hue="class", data=df, palette="coolwarm")
plt.title("Ring Number Distribution by Class")
plt.xlabel("Ring Number")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="ring-type", hue="class", data=df, palette="coolwarm")
plt.title("Ring Color Distribution by Class")
plt.xlabel("Ring Color")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="spore-print-color", hue="class", data=df, palette="coolwarm")
plt.title("Spore Print Color Distribution by Class")
plt.xlabel("Cap Color")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="population", hue="class", data=df, palette="coolwarm")
plt.title("Population Distribution by Class")
plt.xlabel("Population")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="habitat", hue="class", data=df, palette="coolwarm")
plt.title("Habitat Distribution by Class")
plt.xlabel("Habitat")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="class", hue="class", data=df, palette="coolwarm")
plt.title("Class Distribution by Class")
plt.xlabel("Class")
plt.ylabel("Count")
plt.legend(title="Class", labels=["Edible", "Poisonous"])
plt.show()

# %%
print(df_encoded.describe())
# Out:
#          cap-shape  cap-surface    cap-color   bruises%3F         odor  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      3.348104     1.827671     4.504677     0.415559     4.144756
# std       1.604329     1.229873     2.545821     0.492848     2.103729
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     3.000000     0.000000     2.000000
# 50%       3.000000     2.000000     4.000000     0.000000     5.000000
# 75%       5.000000     3.000000     8.000000     1.000000     5.000000
# max       5.000000     3.000000     9.000000     1.000000     8.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      8124.000000   8124.000000  8124.000000  8124.000000  8124.000000
# mean          0.974151      0.161497     0.309207     4.810684     0.567208
# std           0.158695      0.368011     0.462195     3.540359     0.495493
# ...

# %%
print("\nKey Insights:")
print("- The dataset has", df.shape[0], "rows and", df.shape[1], "columns.")
print("- Some features are highly correlated, affecting predictive modeling.")
#print("- There were", outliers.sum().sum(), "outliers detected, which were removed for analysis.")
# Out:
# Key Insights:
# - The dataset has 8124 rows and 23 columns.
# - Some features are highly correlated, affecting predictive modeling.

# %%
from sklearn.preprocessing import LabelEncoder
df_encoded=df.apply(LabelEncoder().fit_transform)
print(df_encoded.head(10))
# Out:
#    cap-shape  cap-surface  cap-color  bruises%3F  odor  gill-attachment  \
# 0          5            2          4           1     6                1
# 1          5            2          9           1     0                1
# 2          0            2          8           1     3                1
# 3          5            3          8           1     6                1
# 4          5            2          3           0     5                1
# 5          5            3          9           1     0                1
# 6          0            2          8           1     0                1
# 7          0            3          8           1     3                1
# 8          5            3          8           1     6                1
# 9          0            2          9           1     0                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# ...
